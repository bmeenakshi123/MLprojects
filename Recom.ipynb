# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('recom.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Main_ID Transaction_ID                     Date  Price  \
# 0           0  90fada91       264f7a69  2022-10-07 20:53:49.153  125.0
# 1           1  9006f9ac       45c7d853  2022-09-17 15:54:57.187   19.0
# 2           2  32270891       61ad76dd  2022-11-28 13:51:55.667  141.0
# 3           3  97e03e47       41ee09f6  2022-09-12 16:20:22.110    4.5
# 4           4  41949228       244fe6d8  2022-10-14 18:53:43.933  129.5
#
#    Code_Product  Amount  ItemKey
# 0        5002.0     1.0   5002.0
# 1       35012.0     1.0      NaN
# 2        5005.0     1.0   5005.0
# 3       35078.5     1.0      NaN
# 4       49291.5     5.0      NaN

# %%
df.describe()
# Out:
#          Unnamed: 0         Price   Code_Product        Amount       ItemKey
# count  50000.000000  50000.000000   50000.000000  50000.000000  28597.000000
# mean   24999.500000     62.560670   32379.293540      1.232640  20775.740952
# std    14433.901067     68.269624   21697.500334      0.749353  16481.882853
# min        0.000000      0.500000    5000.500000      1.000000   5000.500000
# 25%    12499.750000     24.500000   10013.000000      1.000000   5011.500000
# 50%    24999.500000     45.500000   40009.500000      1.000000  10023.000000
# 75%    37499.250000     83.000000   49291.500000      1.000000  40028.500000
# max    49999.000000   2525.500000  350027.500000     54.000000  57035.500000

# %%
df.shape
# Out:
# (50000, 8)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Main_ID', 'Transaction_ID', 'Date', 'Price',
#        'Code_Product', 'Amount', 'ItemKey'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Main_ID               0
# Transaction_ID        0
# Date                  0
# Price                 0
# Code_Product          0
# Amount                0
# ItemKey           21403
# dtype: int64

# %%
df[df['Code_Product']==0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Main_ID, Transaction_ID, Date, Price, Code_Product, Amount, ItemKey]
# Index: []

# %%
df['ItemKey'].notnull().sum()
# Out:
# 28597

# %%
df[df['ItemKey'].notnull()].loc[df['ItemKey']!=df['Code_Product']].sum()
# Out:
# Unnamed: 0        0.0
# Main_ID           0.0
# Transaction_ID    0.0
# Date              0.0
# Price             0.0
# Code_Product      0.0
# Amount            0.0
# ItemKey           0.0
# dtype: float64

# %%
df.drop(['Unnamed: 0','ItemKey'],
             axis=1,
             inplace=True)

# %%
df.head()
# Out:
#     Main_ID Transaction_ID                     Date  Price  Code_Product  \
# 0  90fada91       264f7a69  2022-10-07 20:53:49.153  125.0        5002.0
# 1  9006f9ac       45c7d853  2022-09-17 15:54:57.187   19.0       35012.0
# 2  32270891       61ad76dd  2022-11-28 13:51:55.667  141.0        5005.0
# 3  97e03e47       41ee09f6  2022-09-12 16:20:22.110    4.5       35078.5
# 4  41949228       244fe6d8  2022-10-14 18:53:43.933  129.5       49291.5
#
#    Amount
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     5.0

# %%
pt = df.pivot_table(index="Main_ID", columns=["Code_Product"], values="Amount", aggfunc=np.sum, fill_value=0)

# %%
pt.head()
# Out:
# Code_Product  5000.5    5001.0    5001.5    5002.0    5002.5    5003.0    \
# Main_ID
# 00024de6             0         0         0         0         0         0
# 00084856             0         0         0         0         0         0
# 0008e848             0         0         0         0         0         0
# 00096930             0         0         0         0         0         0
# 000c66b7             0         0         0         1         0         0
#
# Code_Product  5004.0    5004.5    5005.0    5007.0    ...  200035.5  200037.0  \
# Main_ID                                               ...
# 00024de6             0         0         0         0  ...         0         0
# 00084856             0         0         0         0  ...         0         0
# 0008e848             0         0         0         0  ...         0         0
# 00096930             0         0         0         0  ...         0         0
# ...

# %%
df[df['Main_ID']=='90fada91']
# Out:
#     Main_ID Transaction_ID                     Date  Price  Code_Product  \
# 0  90fada91       264f7a69  2022-10-07 20:53:49.153  125.0        5002.0
#
#    Amount
# 0     1.0

# %%
pt.query('Main_ID==["90fada91"]')
# Out:
# Code_Product  5000.5    5001.0    5001.5    5002.0    5002.5    5003.0    \
# Main_ID
# 90fada91             0         0         0         1         0         0
#
# Code_Product  5004.0    5004.5    5005.0    5007.0    ...  200035.5  200037.0  \
# Main_ID                                               ...
# 90fada91             0         0         0         0  ...         0         0
#
# Code_Product  200037.5  200038.0  200038.5  200045.5  200046.0  200046.5  \
# Main_ID
# 90fada91             0         0         0         0         0         0
#
# Code_Product  200047.0  350027.5
# Main_ID
# 90fada91             0         0
#
# [1 rows x 333 columns]

# %%
df.nunique()
# Out:
# Main_ID           28514
# Transaction_ID    48403
# Date              48398
# Price               795
# Code_Product        333
# Amount               22
# dtype: int64

# %%
df.groupby('Main_ID')['Amount'].sum()
# Out:
# Main_ID
# 00024de6    2.0
# 00084856    2.0
# 0008e848    1.0
# 00096930    2.0
# 000c66b7    2.0
#            ...
# fff8b1c4    1.0
# fff905d0    1.0
# fff9726b    2.0
# fffa332b    1.0
# ffff4aa9    1.0
# Name: Amount, Length: 28514, dtype: float64

# %%
list_products_user = pt.query('Main_ID==["00084856"]')
products_for_user = list(list_products_user[list_products_user!=0].dropna(axis=1).columns)
products_for_user
# Out:
# [49291.5, 49292.0]

# %%
list_products_user
# Out:
# Index(['00084856'], dtype='object', name='Main_ID')

# %%
correlation_matrix.iloc[273]
# Out:
# Code_Product
# 5000.5      0.119490
# 5001.0      0.059278
# 5001.5      0.057635
# 5002.0      0.042339
# 5002.5     -0.000003
#               ...
# 200045.5   -0.004716
# 200046.0   -0.004971
# 200046.5   -0.002029
# 200047.0   -0.002029
# 350027.5   -0.002870
# Name: 49291.5, Length: 333, dtype: float64

# %%
correlation_matrix = pt.corr()

# %%
correlation_matrix.head()
# Out:
# Code_Product  5000.5    5001.0    5001.5    5002.0    5002.5    5003.0    \
# Code_Product
# 5000.5        1.000000  0.153768  0.084167  0.136879 -0.003353  0.002358
# 5001.0        0.153768  1.000000  0.063253  0.140715 -0.001517  0.000559
# 5001.5        0.084167  0.063253  1.000000  0.038621 -0.001557  0.007257
# 5002.0        0.136879  0.140715  0.038621  1.000000 -0.001741  0.019406
# 5002.5       -0.003353 -0.001517 -0.001557 -0.001741  1.000000 -0.000407
#
# Code_Product  5004.0    5004.5    5005.0    5007.0    ...  200035.5  200037.0  \
# Code_Product                                          ...
# 5000.5       -0.003475  0.051860  0.044544  0.032989  ... -0.005366 -0.002499
# 5001.0       -0.002629  0.063205  0.134752  0.039826  ... -0.002428 -0.001131
# 5001.5        0.007319  0.002618  0.020729  0.060464  ... -0.002492 -0.001161
# 5002.0       -0.003016  0.044679  0.027020  0.010047  ... -0.002786 -0.001298
# ...

# %%
correlation_matrix.shape
# Out:
# (333, 333)

# %%
pt.query('Main_ID==["00084856"]')
# Out:
# Code_Product  5000.5    5001.0    5001.5    5002.0    5002.5    5003.0    \
# Main_ID
# 00084856             0         0         0         0         0         0
#
# Code_Product  5004.0    5004.5    5005.0    5007.0    ...  200035.5  200037.0  \
# Main_ID                                               ...
# 00084856             0         0         0         0  ...         0         0
#
# Code_Product  200037.5  200038.0  200038.5  200045.5  200046.0  200046.5  \
# Main_ID
# 00084856             0         0         0         0         0         0
#
# Code_Product  200047.0  350027.5
# Main_ID
# 00084856             0         0
#
# [1 rows x 333 columns]

# %%
# contains corr of products for all customers
arr1 = np.dot(pt.query('Main_ID==["00084856"]'), correlation_matrix)

# %%
arr1
# Out:
# array([[ 2.33090370e-01,  1.31361372e-01,  1.05208517e-01,
#          8.12888034e-02, -4.40780332e-03, -1.13375035e-02,
#         -1.30776032e-02,  8.83166363e-02,  2.20177751e-01,
#          3.75642246e-03, -5.65595642e-03,  1.24101482e-01,
#          1.53719645e-04,  1.03507786e-01,  1.04189947e-01,
#          4.39545304e-02, -1.25038273e-03, -2.10100821e-03,
#          7.59120948e-02,  2.83522100e-02,  2.64422286e-02,
#         -3.99929500e-03,  2.58246997e-02, -8.48430659e-03,
#          4.17354715e-02,  5.54463354e-02,  2.83201417e-02,
#          1.19008708e-02, -4.76045450e-03, -1.04108154e-03,
#          1.05678608e-01,  1.63168876e-02,  4.04077497e-02,
#          2.54947147e-01,  1.26875343e-01,  9.19951279e-02,
#          3.35060470e-02, -8.93768697e-03, -1.13238981e-02,
#         -4.69905971e-03,  7.57150254e-02,  7.34877128e-02,
#          1.42007303e-01,  3.43441880e-02,  7.57073873e-03,
#          1.56341305e-01,  1.10150279e-02,  1.15561617e-01,
# ...

# %%
sorted_arr_top10 = arr1[0].argsort()[-10:][::-1]
sorted_arr_top10
# Out:
# array([273, 274,  33,   0,   8,  89, 245, 253,  45,  42], dtype=int64)

# %%
# make sure not negative correlation and not the product purchased by user
recommendations_list = []
for i in range(10):
    to_recommend_product = correlation_matrix.iloc[sorted_arr_top10[i]].name
    print(to_recommend_product)
    correlation =-1
    if to_recommend_product not in products_for_user:
        #make sure positive correlation and find highest correlation
        for product in products_for_user:
            if correlation_matrix[product][to_recommend_product] >0:
                add=True
                correlation = max(correlation,  correlation_matrix[product][to_recommend_product])
        if add:
            recommendations_list.append((to_recommend_product, correlation))
        if len(recommendations_list)==5:
            break
recommendations_list
# Out:
# 49291.5
# 49292.0
# 10006.0
# 5000.5
# 5005.0
# 25003.0
# 45004.0
# [(10006.0, 0.15033928582619197),
#  (5000.5, 0.11948975046667894),
#  (5005.0, 0.12445067163072336),
#  (25003.0, 0.09841382636413923),
#  (45004.0, 0.08770244536161684)]

# %%
arr_given_customer.shape
# Out:
# (333,)

# %%
pt_items_to_customer = df.pivot_table(index="Code_Product", columns=["Main_ID"], values="Amount", aggfunc=np.sum, fill_value=0)
pt_items_to_customer.head()
# Out:
# Main_ID       00024de6  00084856  0008e848  00096930  000c66b7  000e98ee  \
# Code_Product
# 5000.5               0         0         0         0         0         0
# 5001.0               0         0         0         0         0         0
# 5001.5               0         0         0         0         0         0
# 5002.0               0         0         0         0         1         0
# 5002.5               0         0         0         0         0         0
#
# Main_ID       00165e2e  00171ffd  0019e439  001a93a4  ...  ffe473f3  ffe9b45e  \
# Code_Product                                          ...
# 5000.5               0         0         0         0  ...         0         0
# 5001.0               0         0         0         0  ...         0         0
# 5001.5               0         0         0         0  ...         0         0
# 5002.0               0         0         0         0  ...         0         0
# ...

# %%
pt.query('Main_ID==["00084856"]')
# Out:
# Code_Product  5000.5    5001.0    5001.5    5002.0    5002.5    5003.0    \
# Main_ID
# 00084856             0         0         0         0         0         0
#
# Code_Product  5004.0    5004.5    5005.0    5007.0    ...  200035.5  200037.0  \
# Main_ID                                               ...
# 00084856             0         0         0         0  ...         0         0
#
# Code_Product  200037.5  200038.0  200038.5  200045.5  200046.0  200046.5  \
# Main_ID
# 00084856             0         0         0         0         0         0
#
# Code_Product  200047.0  350027.5
# Main_ID
# 00084856             0         0
#
# [1 rows x 333 columns]

# %%
pt_items_to_customer.head()
# Out:
# Main_ID       00024de6  00084856  0008e848  00096930  000c66b7  000e98ee  \
# Code_Product
# 5000.5               0         0         0         0         0         0
# 5001.0               0         0         0         0         0         0
# 5001.5               0         0         0         0         0         0
# 5002.0               0         0         0         0         1         0
# 5002.5               0         0         0         0         0         0
#
# Main_ID       00165e2e  00171ffd  0019e439  001a93a4  ...  ffe473f3  ffe9b45e  \
# Code_Product                                          ...
# 5000.5               0         0         0         0  ...         0         0
# 5001.0               0         0         0         0  ...         0         0
# 5001.5               0         0         0         0  ...         0         0
# 5002.0               0         0         0         0  ...         0         0
# ...

# %%
pt1 = df.pivot_table(index="Code_Product", columns=["Main_ID"], values="Amount", aggfunc=np.sum, fill_value=0)
user_similarity = pt1.corr()
user_similarity.head()
# Out:
# Main_ID   00024de6  00084856  0008e848  00096930  000c66b7  000e98ee  \
# Main_ID
# 00024de6  1.000000 -0.004266 -0.003012 -0.003012 -0.004266 -0.004046
# 00084856 -0.004266  1.000000 -0.004266  0.706041 -0.006042  0.948397
# 0008e848 -0.003012 -0.004266  1.000000 -0.003012 -0.004266 -0.004046
# 00096930 -0.003012  0.706041 -0.003012  1.000000 -0.004266  0.894158
# 000c66b7 -0.004266 -0.006042 -0.004266 -0.004266  1.000000 -0.005730
#
# Main_ID   00165e2e  00171ffd  0019e439  001a93a4  ...  ffe473f3  ffe9b45e  \
# Main_ID                                           ...
# 00024de6 -0.003012 -0.003012 -0.004046 -0.003012  ... -0.003012 -0.003012
# 00084856 -0.004266 -0.004266 -0.005730 -0.004266  ... -0.004266 -0.004266
# 0008e848 -0.003012 -0.003012 -0.004046 -0.003012  ... -0.003012 -0.003012
# 00096930 -0.003012 -0.003012 -0.004046 -0.003012  ... -0.003012 -0.003012
# 000c66b7 -0.004266 -0.004266 -0.005730 -0.004266  ... -0.004266 -0.004266
#
# ...

# %%
user_similarity["00084856"]["02a1970c"]
# Out:
# -0.0042661091131596905

# %%
arr2 = np.dot(pt_items_to_customer, user_similarity["00084856"])

# %%
arr2
# Out:
# array([ 4.65884435e+02,  6.78297145e+01,  5.82833739e+01,  7.57354453e+01,
#         2.36319156e-01,  1.50331549e+00,  4.03040208e-01,  1.28086711e+01,
#         1.48127497e+01,  2.99236833e+00, -1.86731698e-02,  1.13641068e+02,
#         1.10137094e+00,  9.61233455e+01,  8.34467347e+01,  5.06304524e+00,
#         1.36826490e+00,  1.39910915e+00,  4.67087522e+01,  5.69411470e+00,
#         5.34011492e+00, -1.08813530e-02,  2.53442749e+01, -3.75201430e-02,
#         3.21580245e+01,  2.28553260e+01,  8.13544880e+00,  1.95385037e+00,
#         1.97523557e-01,  6.39142103e-01,  5.07701865e+01,  5.51553623e+00,
#         3.36908793e+01,  3.73194139e+00,  1.59490887e+02,  6.97996524e+01,
#         6.79364118e+00,  7.39996688e-01,  5.87023828e-01,  5.96186694e-01,
#         5.37973518e+01,  4.92192129e+01,  3.81886777e+01,  2.50162168e+01,
#         3.87808731e-01,  4.95068443e+00,  1.82237079e+00,  5.76408266e+01,
# ...

# %%
sorted_arr_top10_users = arr2.argsort()[-10:][::-1]
sorted_arr_top10_users
# Out:
# array([274, 273,   0, 245,  34,  89, 249, 253, 240,  11], dtype=int64)

# %%
# recommendations based on other similar customer purchase
recommendations_list_from_customers = []
for i in range(10):
    to_recommend_product = pt_items_to_customer.iloc[sorted_arr_top10_users[i]].name
    print(to_recommend_product)
    correlation =-1
    if to_recommend_product not in products_for_user:
        recommendations_list_from_customers.append(to_recommend_product)
        if len(recommendations_list_from_customers)==5:
            break
recommendations_list_from_customers
# Out:
# 49292.0
# 49291.5
# 5000.5
# 45004.0
# 10013.0
# 25003.0
# 48504.5
# [5000.5, 45004.0, 10013.0, 25003.0, 48504.5]

# %%
df.describe()
# Out:
#               Price   Code_Product        Amount
# count  50000.000000   50000.000000  50000.000000
# mean      62.560670   32379.293540      1.232640
# std       68.269624   21697.500334      0.749353
# min        0.500000    5000.500000      1.000000
# 25%       24.500000   10013.000000      1.000000
# 50%       45.500000   40009.500000      1.000000
# 75%       83.000000   49291.500000      1.000000
# max     2525.500000  350027.500000     54.000000

# %%
df2 = df.copy()
df2['bin'] = pd.cut(df2['Price']/df2['Amount'], [0, 50, 100, 150, 200], labels=['0-50', '50-100', '100-150', '>150'])
df2.head()
#df2.columns
df.loc[(df['Code_Product'] ==5004.5) & (df['Price']>100)].head(5)
# Out:
#        Main_ID Transaction_ID                     Date  Price  Code_Product  \
# 439   0b124772       b4890eb1  2022-09-18 19:55:12.227  111.0        5004.5
# 1883  ddc16d3f       1b5afd1b  2022-08-30 20:02:13.803  161.5        5004.5
# 1984  96a73864       b8671e37  2022-09-28 15:50:56.320  129.5        5004.5
# 2716  0caff03c       58cd3fa6  2022-10-10 20:43:34.667  527.0        5004.5
# 2976  86f7899a       05820f2e  2022-10-06 19:27:25.657  221.5        5004.5
#
#       Amount
# 439      1.0
# 1883     2.0
# 1984     1.0
# 2716     1.0
# 2976     2.0

# %%
pt_price_range_to_items = df2.pivot_table(index="bin", columns=["Code_Product"], values="Amount", aggfunc=sum, fill_value=0)
pt_price_range_to_items
# Out:
# Code_Product  5000.5    5001.0    5001.5    5002.0    5002.5    5003.0    \
# bin
# 0-50              2139        89       270       314         0        26
# 50-100            1769       331       157       300         3         7
# 100-150            582       159        52       112         2         1
# >150               171        51        22        42         0         2
#
# Code_Product  5004.0    5004.5    5005.0    5007.0    ...  200035.5  200037.0  \
# bin                                                   ...
# 0-50                 9        42         0         9  ...        16         5
# 50-100               3        40        25        10  ...         0         0
# 100-150              2        16        19         5  ...         0         0
# >150                 1         5        10         3  ...         0         0
#
# Code_Product  200037.5  200038.0  200038.5  200045.5  200046.0  200046.5  \
# bin
# ...

# %%
pt.query('Main_ID==["00084856"]')
# Out:
# Code_Product  5000.5    5001.0    5001.5    5002.0    5002.5    5003.0    \
# Main_ID
# 00084856             0         0         0         0         0         0
#
# Code_Product  5004.0    5004.5    5005.0    5007.0    ...  200035.5  200037.0  \
# Main_ID                                               ...
# 00084856             0         0         0         0  ...         0         0
#
# Code_Product  200037.5  200038.0  200038.5  200045.5  200046.0  200046.5  \
# Main_ID
# 00084856             0         0         0         0         0         0
#
# Code_Product  200047.0  350027.5
# Main_ID
# 00084856             0         0
#
# [1 rows x 333 columns]

# %%
bin_customer_product = np.dot(pt.query('Main_ID==["00084856"]'),pt_price_range_to_items.T)
bin_customer_product
# Out:
# array([[9120, 2184,  308,   61]], dtype=int64)

# %%
recommendations_list
# Out:
# [(10006.0, 0.15033928582619197),
#  (5000.5, 0.11948975046667894),
#  (5005.0, 0.12445067163072336),
#  (25003.0, 0.09841382636413923),
#  (45004.0, 0.08770244536161684)]

# %%
pt_price_range_to_items[10006.0]
# Out:
# bin
# 0-50       0
# 50-100     4
# 100-150    1
# >150       0
# Name: 10006.0, dtype: int64

# %%
pt_price_range_to_items[25003.0]
# Out:
# bin
# 0-50       468
# 50-100     442
# 100-150    221
# >150        70
# Name: 25003.0, dtype: int64

# %%
pt_price_range_to_items[45004.0]
# Out:
# bin
# 0-50       3477
# 50-100      872
# 100-150     119
# >150         31
# Name: 45004.0, dtype: int64
